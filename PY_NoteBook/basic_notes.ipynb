# %% [markdown]
# NoteBook

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Variables

# %%
num=8
type(num)
# Out:
# int

# %%
num = 5.5
num2=3+5j
print(type(num))
print(type(num2))
# Out:
# <class 'float'>
# <class 'complex'>

# %%
print(10/3) #print decimal value
print(10//3) #print integer value
print(2**3) #print power value
print(2%3) #print remainder value
# Out:
# 3.3333333333333335
# 3
# 8
# 2

# %%
x="55" #string value
x=int(x) #convert string to integer
x=complex(x) #convert string to complex
print(type(x)) #print type of x
# Out:
# <class 'complex'>

# %%
import math
x=math.sqrt(25) #find square root
print(x)
math.e
math.pi
# Out:
# 5.0
# 3.141592653589793

# %% [markdown]
# List
# A list collection fo data. it can hold values of multiple data types

# %%
list1=[1,89,3,7,0,5] #list
print(list1)
list2=['abs','add','all','any'] #list
print(list2)
list3=["ArithmeticError","AssertionError","AttributeError"] #list
print(list3)
list4=[3,5,"get",'A']
print(list4)
# Out:
# [1, 89, 3, 7, 0, 5]
# ['abs', 'add', 'all', 'any']
# ['ArithmeticError', 'AssertionError', 'AttributeError']
# [3, 5, 'get', 'A']

# %%
mat=[[1,2,3],[4,5,6],['a','b','c']] #matrix
print(mat)
# Out:
# [[1, 2, 3], [4, 5, 6], ['a', 'b', 'c']]

# %% [markdown]
# Accesing elements in lists

# %%
word=["welcome","to","python","programming","language"] #list
print(word)
# Out:
# ['welcome', 'to', 'python', 'programming', 'language']
